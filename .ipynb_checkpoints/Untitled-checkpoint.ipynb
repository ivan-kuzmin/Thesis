# %%
P = [0.9764016187692028, 0.9610706000309939, 0.9361848795451982, 0.9120889707316477, 0.8967553847884518, 0.8517319191561427, 0.8377200060640306, 0.8124736302168262, 0.7790434901818566, 0.729234726306221, 0.5277251208104107, 0.43747637363594366, 0.402175070912169, 0.375693844035697, 0.35392969827989645, 0.3529560701007985, 0.2944101334039343, 0.30385829135842335, 0.290546246968597, 0.27837696441885584, 0.26717330565950825]
X = [1.81, 3.62, 5.44, 7.25, 9.06, 10.9, 12.68, 14.49, 16.3, 18.11, 20, 26, 32, 38, 44, 50, 60, 65, 70, 75, 80]
R = [43, 42.1, 41.2, 40.3, 39.4, 38.4, 37.6, 36.7, 35.8, 34.9, 34, 34.3, 34.6, 34.9, 35.2, 35.5, 35.8, 36.1, 36.4, 36.7, 37]

# %%
print(P)
print(X)
# Out:
# [0.9764016187692028, 0.9610706000309939, 0.9361848795451982, 0.9120889707316477, 0.8967553847884518, 0.8517319191561427, 0.8377200060640306, 0.8124736302168262, 0.7790434901818566, 0.729234726306221, 0.5277251208104107, 0.43747637363594366, 0.402175070912169, 0.375693844035697, 0.35392969827989645, 0.3529560701007985, 0.2944101334039343, 0.30385829135842335, 0.290546246968597, 0.27837696441885584, 0.26717330565950825]
# [1.81, 3.62, 5.44, 7.25, 9.06, 10.9, 12.68, 14.49, 16.3, 18.11, 20, 26, 32, 38, 44, 50, 60, 65, 70, 75, 80]

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
# Добавление на рисунок прямоугольной (по умолчанию) области рисования
# scatter1 = plt.scatter(0.0, 1.0)
print('Scatter: ', type(scatter1))

graph1 = plt.plot(X, P)
graph2 = plt.plot(X, R)
print('Plot: ', len(graph1), graph1)

# text1 = plt.text(0.5, 0.5, 'Text on figure')
print('Text: ', type(text1))

grid1 = plt.grid(True)   # линии вспомогательной сетки

# save(name='pic_2_1', fmt='pdf')
# save(name='pic_2_1', fmt='png')

plt.show()
# Out:
# Scatter:  <class 'matplotlib.collections.PathCollection'>
# Plot:  1 [<matplotlib.lines.Line2D object at 0x1147880f0>]
# Text:  <class 'matplotlib.text.Text'>

# %%
import matplotlib.pyplot as plt

x_values1=[1,2,3,4,5]
y_values1=[1,2,2,4,1]

x_values2=[-1000,-800,-600,-400,-200]
y_values2=[10,20,39,40,50]

x_values3=[150,200,250,300,350]
y_values3=[10,20,30,40,50]


fig=plt.figure()
ax=fig.add_subplot(111, label="1")
ax2=fig.add_subplot(111, label="2", frame_on=False)
ax3=fig.add_subplot(111, label="3", frame_on=False)

ax.plot(x_values1, y_values1, color="C0")
ax.set_xlabel("x label 1", color="C0")
ax.set_ylabel("y label 1", color="C0")
ax2.yaxis.set_label_coords(-0.15, 1.1)
ax.tick_params(axis='x', colors="C0")
ax.tick_params(axis='y', colors="C0")

ax2.scatter(x_values2, y_values2, color="C1")
# ax2.xaxis.tick_top()
# ax2.yaxis.tick_left()
ax2.set_xlabel('x label 2', color="C1") 
ax2.set_ylabel('y label 2', color="C1")       
ax2.xaxis.set_label_position('top') 
# ax2.yaxis.set_label_position('left')
ax2.yaxis.set_label_coords(-0.15, 1.1)
ax2.tick_params(axis='x', colors="C1")
ax2.tick_params(axis='y', colors="C1", pad=50)

ax3.plot(x_values3, y_values3, color="C3")
ax3.set_xticks([])
ax3.set_yticks([])

plt.show()
